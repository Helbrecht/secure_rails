# %%
# %pylab inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
import sklearn
from sklearn.cluster import KMeans
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv('data_for_class.csv')
data['total'] = data.sum(axis=1)
data
# Out:
#                source  United States  Vietnam  Germany  United Kingdom  \
# 0             Vxvault              7        1        2               1
# 1            Autoshun              3        0        0               0
# 2          Alienvault              1        0        0               0
# 3             Hphosts              6        0        0               2
# 4       BlocklistDeIp              0        0        0               0
# 5            Botscout              0        0        0               0
# 6                Cert             21        0        0               2
# 7               Chaos              0        0        0               0
# 8            Cinscore              1        0        0               0
# 9   MalvareDomainUrls              0        0        0               0
# 10         Ransomware             15        1        3               1
# 11      ThreatcrowdIp              3        0        0               0
# ...

# %%
letters = data[["match_letter_1", "match_letter_2"]]
